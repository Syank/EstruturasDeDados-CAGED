# %%
import pandas
import matplotlib.pyplot as plt
import numpy
import os

# %%
dicionarioMeses = {
    1: "Janeiro", 
    2: "Fevereiro", 
    3: "Março", 
    4: "Abril", 
    5: "Maio", 
    6: "Junho", 
    7: "Julho", 
    8: "Agosto",
    9: "Setembro", 
    10: "Outubro", 
    11: "Novembro", 
    12: "Dezembro"
}

def pegarNomeMes(numeroMes):
    return dicionarioMeses[numeroMes]

# %%
dicionarioDeDados = {
    "sexo": {
        1: "Homem",
        3: "Mulher",
        9: "Não identificado"
    },
    "tipomovimentação": {
        10: "Admissão", #"Admissão por primeiro emprego",
        20: "Admissão", #"Admissão por reemprego,"
        25: "Admissão", #"Admissão por contrato trabalho prazo determinado",
        31: "Demissão", #"Desligamento por demissão sem justa causa",
        32: "Demissão", #"Desligamento por demissão com justa causa",
        33: "Demissão", #"Culpa Recíproca",
        35: "Admissão", #"Admissão por reintegração",
        40: "Demissão", #"Desligamento a pedido",
        43: "Demissão", #"Término contrato trabalho prazo determinado",
        45: "Demissão", #"Desligamento por Término de contrato",
        50: "Demissão", #"Desligamento por aposentadoria",
        60: "Demissão", #"Desligamento por morte",
        70: "Admissão", #"Admissão por transferência",
        80: "Demissão", #"Desligamento por transferência",
        90: "Demissão", #"Desligamento por Acordo entre empregado e empregador",
        98: "Demissão", #"Desligamento de Tipo Ignorado",
        99: "Não Identificado"
    },
    "município": {
        "Região 1": {
            350850: "Caçapava",            # Grupo 1
            352020: "Igaratá",             # Grupo 1
            352440: "Jacareí",             # Grupo 1
            352490: "Jambeiro",            # Grupo 1
            353170: "Monteiro Lobato",     # Grupo 1
            353560: "Paraíbuna",           # Grupo 1
            354600: "Santa Branca",        # Grupo 1
            354990: "São José dos Campos", # Grupo 1
        },
        "Região 2": {
            350970: "Campos do Jordão",        # Grupo 2
            352630: "Lagoinha",                # Grupo 2
            353230: "Natividade da Serra",     # Grupo 2
            353800: "Pindamonhangaba",         # Grupo 2
            354230: "Redenção da Serra",       # Grupo 2
            354820: "Santo Antônio do Pinhal", # Grupo 2
            354860: "São Bento do Sapucaí",    # Grupo 2
            355000: "São Luiz do Paraitinga",  # Grupo 2
            355410: "Taubaté",                 # Grupo 2
            355480: "Tremembé",                # Grupo 2
        },
        "Região 3": {
            350250: "Aparecida",          # Grupo 3
            350860: "Cachoeira Paulista", # Grupo 3
            350995: "Canas",              # Grupo 3
            351360: "Cunha",              # Grupo 3
            351840: "Guaratinguetá",      # Grupo 3
            352720: "Lorena",             # Grupo 3
            353850: "Piquete",            # Grupo 3
            354075: "Potim",              # Grupo 3
            354430: "Roseira",            # Grupo 3
        },
        "Região 4": {
            350315: "Arapeí",               # Grupo 4
            350350: "Areias",               # Grupo 4
            350490: "Bananal",              # Grupo 4
            351340: "Cruzeiro",             # Grupo 4
            352660: "Lavrinhas",            # Grupo 4
            354190: "Queluz",               # Grupo 4
            354960: "São José do Barreiro", # Grupo 4
            355200: "Silveiras",            # Grupo 4
        },
        "Região 5": {
            351050: "Caraguatatuba", # Grupo 5
            352040: "Ilhabela",      # Grupo 5
            355070: "São Sebastião", # Grupo 5
            355540: "Ubatuba"        # Grupo 5
        }
    },
    "raçacor": {
        1: "Branca",
        2: "Preta",
        3: "Parda",
        4: "Amarela",
        5: "Indígena",
        6: "Não informada",
        9: "Não Identificado"
    }
}

# %%
def lerTabelasDiretorio(ano, colunasUtilizaveis):
    caminhoDados = "../doc/Dados/CAGED"
    
    fonteDados = os.listdir(caminhoDados + "/" + ano)
    
    # Retira os arquivos que não são do tipo .txt da lista
    for arquivo in fonteDados:
        if ".txt" not in arquivo:
            del fonteDados[fonteDados.index(arquivo)]
            
    tabelas = {}
    
    for nomeTabela in fonteDados:
        valorMes = int(nomeTabela.split(".")[0][-2:])  # Pega os dois últimos valores do nome do arquivo, que representam o mês e converte para um inteiro
        nomeMes = pegarNomeMes(valorMes)
        tabelas[nomeMes] = pandas.read_csv(caminhoDados + "/" + ano + "/" + nomeTabela,
                                           delimiter=";",
                                           usecols=colunasUtilizaveis)
        
    return tabelas

# %%
colunasUtilizaveis = ["sexo", "tipomovimentação", "município", "raçacor", "salário"]

dados2020 = lerTabelasDiretorio("2020", colunasUtilizaveis)
dados2021 = lerTabelasDiretorio("2021", colunasUtilizaveis)

# %%
def organizarPorRegiao(dadosCrus):
    novosDados = {}
    
    for mes in dadosCrus:
        for grupoRegiao in dicionarioDeDados["município"]:
            for codigoRegiao in dicionarioDeDados["município"][grupoRegiao]:
                nomeMunicipio = dicionarioDeDados["município"][grupoRegiao][codigoRegiao]
                
                mascara = dadosCrus[mes]["município"] == codigoRegiao
                
                filtrado = dadosCrus[mes][mascara]
                
                if grupoRegiao not in novosDados:
                    novosDados[grupoRegiao] = {
                        nomeMunicipio: {
                            mes: filtrado
                        }
                    }
                elif nomeMunicipio not in novosDados[grupoRegiao]:
                    novosDados[grupoRegiao][nomeMunicipio] = {
                        mes: filtrado
                    }
                else:
                    novosDados[grupoRegiao][nomeMunicipio][mes] = filtrado
        
    return novosDados

# %%
dadosPorRegiao2020 = organizarPorRegiao(dados2020)
dadosPorRegiao2021 = organizarPorRegiao(dados2021)

# %%
dadosPorRegiao2021["Região 1"]["São José dos Campos"]["Janeiro"]["salário"].max()
# Out:
# 505780.0

# %%
def pegarTipoColunaGrupo(grupo, nomeColuna):
    indexColuna = grupo.columns.get_loc(nomeColuna)
    return grupo.sample().values[0][indexColuna]

def filtrarPorEtnia(dados):
    novosDados = {}
    
    for regiao in dados:
        if regiao not in novosDados:
            novosDados[regiao] = {}
        
        for municipio in dados[regiao]:
            if municipio not in novosDados[regiao]:
                novosDados[regiao][municipio] = {}
                
            for mes in dados[regiao][municipio]:
                if mes not in novosDados[regiao][municipio]:
                    novosDados[regiao][municipio][mes] = {}
                    
                grupo = dados[regiao][municipio][mes].groupby(["raçacor"])
                
                for chave, valor in grupo:
                    subgrupo = grupo.get_group(chave)
                    
                    codigoEtnia = int(pegarTipoColunaGrupo(subgrupo, "raçacor"))
                    
                    etnia = dicionarioDeDados["raçacor"][codigoEtnia]
                    mediaSalarial = subgrupo["salário"].mean()

                    if "Média salarial" not in novosDados[regiao][municipio][mes]:
                        novosDados[regiao][municipio][mes]["Média salarial"] = {
                            etnia: mediaSalarial
                        }
                    else:
                        if "Não" not in etnia:  # Filtro para não adicionar informções não iddentificadas ou não informadas
                            novosDados[regiao][municipio][mes]["Média salarial"][etnia] = round(mediaSalarial, 2)  # Arredonda para 2 casas decimais

    return novosDados

# %%
mediaSalarialEtinia2020 = filtrarPorEtnia(dadosPorRegiao2020)
mediaSalarialEtinia2021 = filtrarPorEtnia(dadosPorRegiao2021)

mediaSalarialEtinia2020["Região 1"]
# Out:
# {'Caçapava': {'Janeiro': {'Média salarial': {'Branca': 1759.8179900015014,
#     'Preta': 1415.93,
#     'Parda': 2973.17,
#     'Amarela': 2093.29}},
#   'Fevereiro': {'Média salarial': {'Branca': 1654.2293681631384,
#     'Preta': 1278.2,
#     'Parda': 1645.87,
#     'Amarela': 1650.58,
#     'Indígena': 1558.0}},
#   'Março': {'Média salarial': {'Branca': 1884.890654312842,
#     'Preta': 1409.6,
#     'Parda': 1510.02,
#     'Amarela': 1386.16,
#     'Indígena': 1269.0}},
#   'Abril': {'Média salarial': {'Branca': 1916.2500114467457,
#     'Preta': 1605.78,
#     'Parda': 1675.96}},
#   'Maio': {'Média salarial': {'Branca': 2011.7770749658778,
#     'Preta': 1495.41,
#     'Parda': 1527.38,
#     'Amarela': 3651.52}},
#   'Junho': {'Média salarial': {'Branca': 1996.063996775254,
#     'Preta': 1758.03,
#     'Parda': 1586.03}},
#   'Julho': {'Média salarial': {'Branca': 1808.3004072879223,
#     'Preta': 1615.1,
#     'Parda': 1624.44,
#     'Amarela': 1510.63,
#     'Indígena': 2002.3}},
#   'Agosto': {'Média salarial': {'Branca': 1777.5928395763162,
#     'Preta': 1586.21,
#     'Parda': 1436.94,
#     'Amarela': 2033.53,
#     'Indígena': 2699.4}},
#   'Setembro': {'Média salarial': {'Branca': 1929.0705047994627,
#     'Preta': 1613.41,
#     'Parda': 1961.34,
#     'Amarela': 3128.77}},
#   'Outubro': {'Média salarial': {'Branca': 3702.3430159152463,
#     'Preta': 1877.42,
#     'Parda': 1606.64,
#     'Amarela': 1424.93}},
#   'Novembro': {'Média salarial': {'Branca': 2765.375934453371,
#     'Preta': 1469.74,
#     'Parda': 1541.32,
#     'Amarela': 1448.37,
#     'Indígena': 1534.86}},
#   'Dezembro': {'Média salarial': {'Branca': 2069.208462826883,
#     'Preta': 1760.26,
#     'Parda': 1740.5,
#     'Amarela': 1917.51}}},
#  'Igaratá': {'Janeiro': {'Média salarial': {'Branca': 1774.5195589932528,
#     'Parda': 1369.71}},
#   'Fevereiro': {'Média salarial': {'Branca': 1696.6102746241802,
#     'Preta': 1670.0,
#     'Parda': 1730.93}},
#   'Março': {'Média salarial': {'Branca': 1675.4326332493831,
#     'Preta': 1875.0,
#     'Parda': 1422.83}},
#   'Abril': {'Média salarial': {'Branca': 1354.5727206143465,
#     'Parda': 1292.33}},
#   'Maio': {'Média salarial': {'Branca': 1739.3899972098213,
#     'Preta': 1311.02,
#     'Parda': 1468.31}},
#   'Junho': {'Média salarial': {'Branca': 1479.9709139737215,
#     'Preta': 1528.8,
#     'Parda': 1757.62}},
#   'Julho': {'Média salarial': {'Branca': 1663.4426717122396,
#     'Preta': 1780.0,
#     'Parda': 1551.67}},
#   'Agosto': {'Média salarial': {'Branca': 1717.6573910920517,
#     'Preta': 1550.0,
#     'Parda': 1646.4}},
#   'Setembro': {'Média salarial': {'Branca': 1891.4221321268285,
#     'Preta': 1653.33,
#     'Parda': 1682.86}},
#   'Outubro': {'Média salarial': {'Branca': 1693.6683029621206,
#     'Preta': 1754.02,
#     'Parda': 1619.69}},
#   'Novembro': {'Média salarial': {'Branca': 1741.6692986739308,
#     'Preta': 1620.68,
#     'Parda': 1850.63}},
#   'Dezembro': {'Média salarial': {'Branca': 1925.2389713923137,
#     'Preta': 1688.72,
#     'Parda': 2472.27}}},
#  'Jacareí': {'Janeiro': {'Média salarial': {'Branca': 2036.0177440880946,
#     'Preta': 1600.65,
#     'Parda': 2738.14,
#     'Amarela': 2535.34,
#     'Indígena': 1092.0}},
#   'Fevereiro': {'Média salarial': {'Branca': 3214.9269205576784,
#     'Preta': 4032.9,
#     'Parda': 2468.44,
#     'Amarela': 1825.56,
#     'Indígena': 1463.56}},
#   'Março': {'Média salarial': {'Branca': 1961.37063025253,
#     'Preta': 1690.51,
#     'Parda': 3930.09,
#     'Amarela': 2152.91,
#     'Indígena': 1964.65}},
#   'Abril': {'Média salarial': {'Branca': 3042.6457527277225,
#     'Preta': 1663.01,
#     'Parda': 3119.63,
#     'Amarela': 2064.8,
#     'Indígena': 1841.67}},
#   'Maio': {'Média salarial': {'Branca': 7025.116487031414,
#     'Preta': 1731.97,
#     'Parda': 5170.11,
#     'Amarela': 5653.52}},
#   'Junho': {'Média salarial': {'Branca': 2885.370407584273,
#     'Preta': 1973.15,
#     'Parda': 3259.42,
#     'Amarela': 2471.98,
#     'Indígena': 1451.8}},
#   'Julho': {'Média salarial': {'Branca': 3944.7632226932396,
#     'Preta': 1936.88,
#     'Parda': 7762.11,
#     'Amarela': 2769.53,
#     'Indígena': 3914.53}},
#   'Agosto': {'Média salarial': {'Branca': 2127.948594570893,
#     'Preta': 2068.89,
#     'Parda': 4099.44,
#     'Amarela': 3795.64,
#     'Indígena': 3540.0}},
#   'Setembro': {'Média salarial': {'Branca': 7000.113724883561,
#     'Preta': 1789.41,
#     'Parda': 6845.48,
#     'Amarela': 3094.96,
#     'Indígena': 1466.49}},
#   'Outubro': {'Média salarial': {'Branca': 3786.6026727077583,
#     'Preta': 1892.18,
#     'Parda': 3142.11,
#     'Amarela': 1405.66,
#     'Indígena': 1346.1}},
#   'Novembro': {'Média salarial': {'Branca': 6658.228231476451,
#     'Preta': 1669.68,
#     'Parda': 2171.97,
#     'Amarela': 1909.21,
#     'Indígena': 1280.85}},
#   'Dezembro': {'Média salarial': {'Branca': 4241.305652749701,
#     'Preta': 8160.26,
#     'Parda': 2227.67,
#     'Amarela': 1460.36,
#     'Indígena': 1535.2}}},
#  'Jambeiro': {'Janeiro': {'Média salarial': {'Branca': 5571.933927970097,
#     'Preta': 6002.14,
#     'Parda': 8017.52,
#     'Indígena': 1170.56}},
#   'Fevereiro': {'Média salarial': {'Branca': 5773.49335826527,
#     'Preta': 8088.49,
#     'Parda': 6065.15}},
#   'Março': {'Média salarial': {'Branca': 4376.338182824803,
#     'Preta': 3552.96,
#     'Parda': 2252.55,
#     'Amarela': 7681.79,
#     'Indígena': 1596.4}},
#   'Abril': {'Média salarial': {'Branca': 3526.5964319210243,
#     'Preta': 6997.08,
#     'Parda': 1693.95}},
#   'Maio': {'Média salarial': {'Branca': 2599.8536585365855,
#     'Preta': 8936.47,
#     'Parda': 7211.84}},
#   'Junho': {'Média salarial': {'Branca': 10621.794997442335,
#     'Preta': 6847.98,
#     'Parda': 2207.48}},
#   'Julho': {'Média salarial': {'Branca': 14558.599156697592,
#     'Preta': 6210.29,
#     'Parda': 6705.07}},
#   'Agosto': {'Média salarial': {'Branca': 18652.362328098247,
#     'Preta': 6166.51,
#     'Parda': 6582.02}},
#   'Setembro': {'Média salarial': {'Branca': 10655.639333677685,
#     'Preta': 8217.31,
#     'Parda': 14283.11,
#     'Amarela': 14300.0,
#     'Indígena': 1637.11}},
#   'Outubro': {'Média salarial': {'Branca': 8464.619607944682,
#     'Preta': 2442.59,
#     'Parda': 32218.9}},
#   'Novembro': {'Média salarial': {'Branca': 12413.737865168874,
#     'Preta': 7802.02,
#     'Parda': 15660.3}},
#   'Dezembro': {'Média salarial': {'Branca': 372764.9441423087,
#     'Preta': 3448.53,
#     'Parda': 5257.82,
#     'Amarela': 8008.0}}},
#  'Monteiro Lobato': {'Janeiro': {'Média salarial': {'Branca': 1435.2115337665264}},
#   'Fevereiro': {'Média salarial': {'Branca': 1403.2153836763823,
#     'Parda': 1531.49}},
#   'Março': {'Média salarial': {'Branca': 1174.9468688964844,
#     'Preta': 712.5,
#     'Parda': 954.21}},
#   'Abril': {'Média salarial': {'Branca': 1958.4499925885882, 'Parda': 754.3}},
#   'Maio': {'Média salarial': {'Branca': 1330.2244330512158}},
#   'Junho': {'Média salarial': {'Branca': 1213.9161470853367,
#     'Parda': 1561.36}},
#   'Julho': {'Média salarial': {'Branca': 1084.4024658203127,
#     'Parda': 1079.65}},
#   'Agosto': {'Média salarial': {'Branca': 1553.2685721261162,
#     'Parda': 1381.83}},
#   'Setembro': {'Média salarial': {'Branca': 1410.9349670410156,
#     'Preta': 1449.76}},
#   'Outubro': {'Média salarial': {'Branca': 1404.1512451171875,
#     'Preta': 1338.08,
#     'Parda': 1338.08}},
#   'Novembro': {'Média salarial': {'Branca': 1308.6539957682292,
#     'Preta': 756.27,
#     'Parda': 3024.42}},
#   'Dezembro': {'Média salarial': {'Branca': 1924.382360121783,
#     'Parda': 1991.69}}},
#  'Paraíbuna': {'Janeiro': {'Média salarial': {'Branca': 1429.8455961153104,
#     'Preta': 2236.08,
#     'Parda': 1722.17,
#     'Amarela': 3080.0}},
#   'Fevereiro': {'Média salarial': {'Branca': 1394.6390550401475,
#     'Preta': 2005.45,
#     'Parda': 1655.1}},
#   'Março': {'Média salarial': {'Branca': 1483.2545245942615,
#     'Preta': 2214.33,
#     'Parda': 1648.3}},
#   'Abril': {'Média salarial': {'Branca': 1489.3116428668682,
#     'Preta': 2124.94,
#     'Parda': 1584.06}},
#   'Maio': {'Média salarial': {'Branca': 1335.3803169727325,
#     'Preta': 2102.32,
#     'Parda': 1421.47}},
#   'Junho': {'Média salarial': {'Branca': 1696.6142839704241,
#     'Preta': 2208.2,
#     'Parda': 1598.7,
#     'Amarela': 3080.0}},
#   'Julho': {'Média salarial': {'Branca': 1785.291309557463,
#     'Preta': 2091.29,
#     'Parda': 2779.03}},
#   'Agosto': {'Média salarial': {'Branca': 1617.479645865304,
#     'Preta': 1980.0,
#     'Parda': 1635.27}},
#   'Setembro': {'Média salarial': {'Branca': 1715.1619197764296,
#     'Preta': 2577.17,
#     'Parda': 2054.9,
#     'Amarela': 3080.0}},
#   'Outubro': {'Média salarial': {'Branca': 1754.7644771746734,
#     'Preta': 2354.0,
#     'Parda': 2067.04,
#     'Amarela': 3363.02}},
#   'Novembro': {'Média salarial': {'Branca': 1538.2604089685387,
#     'Preta': 3080.0,
#     'Parda': 1813.1,
#     'Amarela': 3363.02}},
#   'Dezembro': {'Média salarial': {'Branca': 1541.8544736589704,
#     'Preta': 1781.7,
#     'Parda': 2403.44}}},
#  'Santa Branca': {'Janeiro': {'Média salarial': {'Branca': 1457.4273163169944,
#     'Preta': 1614.31,
#     'Parda': 1244.62}},
#   'Fevereiro': {'Média salarial': {'Branca': 4584.2232528135,
#     'Preta': 1599.28,
#     'Parda': 1819.23}},
#   'Março': {'Média salarial': {'Branca': 1454.0884238795231,
#     'Preta': 1744.48,
#     'Parda': 15029.17}},
#   'Abril': {'Média salarial': {'Branca': 1813.222129128196,
#     'Preta': 1143.8,
#     'Parda': 1723.62}},
#   'Maio': {'Média salarial': {'Branca': 1585.3930053710938,
#     'Preta': 1910.04,
#     'Parda': 1762.73,
#     'Amarela': 1326.91,
#     'Indígena': 1326.91}},
#   'Junho': {'Média salarial': {'Branca': 1435.499303181966,
#     'Preta': 1275.54,
#     'Parda': 1345.86}},
#   'Julho': {'Média salarial': {'Branca': 1365.80442835073,
#     'Preta': 2176.23,
#     'Parda': 1509.0,
#     'Amarela': 1556.28}},
#   'Agosto': {'Média salarial': {'Branca': 1467.7628522600446,
#     'Preta': 1870.75,
#     'Parda': 1560.83}},
#   'Setembro': {'Média salarial': {'Branca': 1727.625279017857,
#     'Preta': 1406.65,
#     'Parda': 1599.94,
#     'Amarela': 1373.6}},
#   'Outubro': {'Média salarial': {'Branca': 1521.0421916682546,
#     'Preta': 1655.35,
#     'Parda': 1525.84}},
#   'Novembro': {'Média salarial': {'Branca': 1747.9046434674945,
#     'Preta': 1709.41,
#     'Parda': 1674.89}},
#   'Dezembro': {'Média salarial': {'Branca': 1224.693333890703,
#     'Preta': 1463.97,
#     'Parda': 1281.62}}},
#  'São José dos Campos': {'Janeiro': {'Média salarial': {'Branca': 2315.472210854932,
#     'Preta': 2036.85,
#     'Parda': 1586.8,
#     'Amarela': 1946.35,
#     'Indígena': 1384.68}},
#   'Fevereiro': {'Média salarial': {'Branca': 2258.9534496445267,
#     'Preta': 1664.45,
#     'Parda': 1967.07,
#     'Amarela': 3625.84,
#     'Indígena': 1434.83}},
#   'Março': {'Média salarial': {'Branca': 2026.268825387771,
#     'Preta': 1663.23,
#     'Parda': 1864.56,
#     'Amarela': 2763.97,
#     'Indígena': 1186.94}},
#   'Abril': {'Média salarial': {'Branca': 3160.5258224638064,
#     'Preta': 1518.76,
#     'Parda': 1802.42,
#     'Amarela': 3269.57,
#     'Indígena': 1732.45}},
#   'Maio': {'Média salarial': {'Branca': 2603.4971618852996,
#     'Preta': 1701.82,
#     'Parda': 1939.72,
#     'Amarela': 2261.76,
#     'Indígena': 1368.69}},
#   'Junho': {'Média salarial': {'Branca': 3133.0973668906563,
#     'Preta': 2562.02,
#     'Parda': 2358.72,
#     'Amarela': 3291.86,
#     'Indígena': 2065.69}},
#   'Julho': {'Média salarial': {'Branca': 3027.9893498393553,
#     'Preta': 4459.0,
#     'Parda': 4289.79,
#     'Amarela': 7239.55,
#     'Indígena': 2855.34}},
#   'Agosto': {'Média salarial': {'Branca': 2641.502572071027,
#     'Preta': 2291.83,
#     'Parda': 4695.74,
#     'Amarela': 4441.38,
#     'Indígena': 1685.31}},
#   'Setembro': {'Média salarial': {'Branca': 3313.332843326088,
#     'Preta': 2607.34,
#     'Parda': 3711.33,
#     'Amarela': 6391.16,
#     'Indígena': 1887.28}},
#   'Outubro': {'Média salarial': {'Branca': 2805.437769549576,
#     'Preta': 1936.57,
#     'Parda': 2789.63,
#     'Amarela': 2213.32,
#     'Indígena': 1973.76}},
#   'Novembro': {'Média salarial': {'Branca': 2577.1874138508692,
#     'Preta': 1546.55,
#     'Parda': 2354.53,
#     'Amarela': 48340.91,
#     'Indígena': 1490.0}},
#   'Dezembro': {'Média salarial': {'Branca': 4290.327216839804,
#     'Preta': 1919.13,
#     'Parda': 1843.32,
#     'Amarela': 3531.08,
#     'Indígena': 1289.07}}}}

# %%
def prepararDadosPizza(dadosRegiao):
    dadosPreparados = {}
    
    for municipio in dadosRegiao:
        for mes in dadosRegiao[municipio]:
            dadosPreparados[mes] = {
                "etnia": [],
                "media": []
            }
            
            for etnia in dadosRegiao[municipio][mes]["Média salarial"]:
                dadosPreparados[mes]["etnia"].append(etnia)

                salariosEtniaRegiaoMes = []

                for municipioMediaMes in dadosRegiao:
                    if etnia in dadosRegiao[municipioMediaMes][mes]["Média salarial"]:
                        salariosEtniaRegiaoMes.append(dadosRegiao[municipioMediaMes][mes]["Média salarial"][etnia])

                total = 0
                for salario in salariosEtniaRegiaoMes:
                    total += salario

                dadosPreparados[mes]["media"].append(round(total / len(salariosEtniaRegiaoMes), 2))
    
    return dadosPreparados

def plotarGraficoPizza(dadosPizzaRegiao, regiao, ano):
    for mes in dadosPizzaRegiao:
        etnias = dadosPizzaRegiao[mes]["etnia"]
        salarios = dadosPizzaRegiao[mes]["media"]
        
        plt.pie(salarios, labels=salarios, autopct='%1.1f%%', shadow=True, startangle=90)
        
        #Adiciona Legenda
        plt.legend(etnias, bbox_to_anchor=(1.3, 0.9),loc='upper right')

        #Centraliza o gráfico
        plt.axis('equal')
        
        municipios = dicionarioDeDados["município"][regiao]
        
        titulo = "Média salarial por etnia para o agrupamento de municípios\n"
        
        for municipio in municipios:
            titulo += municipios[municipio] + " "
        
        titulo += "\n" + mes + "/" + ano + "\n"
        
        plt.title(titulo)
        
        #Ajusta o espaçamento para evitar o recorte do rótulo
        plt.tight_layout()

        plt.show()

# %%
dadosPreparadosPizzaRegiao1_2020 = prepararDadosPizza(mediaSalarialEtinia2020["Região 1"])
dadosPreparadosPizzaRegiao2_2020 = prepararDadosPizza(mediaSalarialEtinia2020["Região 2"])
dadosPreparadosPizzaRegiao3_2020 = prepararDadosPizza(mediaSalarialEtinia2020["Região 3"])
#dadosPreparadosPizzaRegiao4_2020 = prepararDadosPizza(mediaSalarialEtinia2020["Região 4"])
dadosPreparadosPizzaRegiao5_2020 = prepararDadosPizza(mediaSalarialEtinia2020["Região 5"])

dadosPreparadosPizzaRegiao1_2021 = prepararDadosPizza(mediaSalarialEtinia2021["Região 1"])
dadosPreparadosPizzaRegiao2_2021 = prepararDadosPizza(mediaSalarialEtinia2021["Região 2"])
dadosPreparadosPizzaRegiao3_2021 = prepararDadosPizza(mediaSalarialEtinia2021["Região 3"])
#dadosPreparadosPizzaRegiao4_2021 = prepararDadosPizza(mediaSalarialEtinia2021["Região 4"])
dadosPreparadosPizzaRegiao5_2021 = prepararDadosPizza(mediaSalarialEtinia2021["Região 5"])

# %%
plotarGraficoPizza(dadosPreparadosPizzaRegiao1_2020, "Região 1", "2020")

# %%
plotarGraficoPizza(dadosPreparadosPizzaRegiao2_2020, "Região 2", "2020")

# %%
plotarGraficoPizza(dadosPreparadosPizzaRegiao3_2020, "Região 3", "2020")

# %%
plotarGraficoPizza(dadosPreparadosPizzaRegiao5_2020, "Região 5", "2020")

# %%
plotarGraficoPizza(dadosPreparadosPizzaRegiao1_2021, "Região 1", "2021")

# %%
plotarGraficoPizza(dadosPreparadosPizzaRegiao2_2021, "Região 2", "2021")

# %%
plotarGraficoPizza(dadosPreparadosPizzaRegiao3_2021, "Região 3", "2021")

# %%
plotarGraficoPizza(dadosPreparadosPizzaRegiao5_2021, "Região 5", "2021")
